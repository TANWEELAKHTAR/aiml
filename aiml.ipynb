# %% [markdown]
# Univariate Analysis

# %%
import matplotlib.pyplot as plt
import numpy as np

fig,ax = plt.subplots(1,1)
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27,63,71,90,92,95,96,32,37,40])
plt.hist(a)
ax.set_xlabel('Marks')
ax.set_ylabel('no. of students')

plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_subplot([0,0,1,1])
courses = ['machine learning','web development','app development']
students_enrolled = [30,25,20]

ax.pie(students_enrolled, labels=courses)

plt.show()

# %% [markdown]
# Bivariate Analysis

# %%
import matplotlib.pyplot as plt

no_of_students = [5,7,8,7,2,16,2,9,4,11,12,9,6]
marks = [80,86,87,88,79,86,87,94,78,77,85,86,90] 

plt.scatter(marks, no_of_students)

plt.xlabel('Marks')
plt.ylabel('No. of Students')

plt.show()

# %% [markdown]
# Handling missing values

# %%
# using isnull()and notnull()

import pandas as pd
import numpy as np
dict = {'First Score':[100, 90, np.nan, 95],
 'Second Score': [30, 45, 56, np.nan],
 'Third Score':[np.nan, 40, 80, 98]}
df = pd.DataFrame(dict)
df.isnull()
# Out:
#    First Score  Second Score  Third Score
# 0        False         False         True
# 1        False         False        False
# 2         True         False        False
# 3        False          True        False

# %%
import pandas as pd
import numpy as np
dict = {'First Score':[100, 90, np.nan, 95],
 'Second Score': [30, 45, 56, np.nan],
 'Third Score':[np.nan, 40, 80, 98]}
df = pd.DataFrame(dict)
df.notnull()
# Out:
#    First Score  Second Score  Third Score
# 0         True          True        False
# 1         True          True         True
# 2        False          True         True
# 3         True         False         True

# %%
# filling a missing value with 0

import pandas as pd
import numpy as np
dict = {'First Score':[100, 90, np.nan, 95],
 'Second Score': [30, 45, 56, np.nan],
 'Third Score':[np.nan, 40, 80, 98]}
df = pd.DataFrame(dict)
df.fillna(0)
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          0.0
# 1         90.0          45.0         40.0
# 2          0.0          56.0         80.0
# 3         95.0           0.0         98.0

# %%
# filling a missing value with previous ones/ffill and bfill using fillna() methods

import pandas as pd
import numpy as np
dict = {'First Score':[100, 90, np.nan, 95],
 'Second Score': [30, 45, 56, np.nan],
 'Third Score':[np.nan, 40, 80, 98]}
df = pd.DataFrame(dict)
df.fillna(method ='pad')
# Out:
# C:\Users\akhta\AppData\Local\Temp\ipykernel_18332\1648962781.py:9: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method ='pad')
#    First Score  Second Score  Third Score
# 0        100.0          30.0          NaN
# 1         90.0          45.0         40.0
# 2         90.0          56.0         80.0
# 3         95.0          56.0         98.0

# %%
import pandas as pd
import numpy as np
dict = {'First Score':[100, 90, np.nan, 95],
 'Second Score': [30, 45, 56, np.nan],
 'Third Score':[np.nan, 40, 80, 98]}
df = pd.DataFrame(dict)
df.fillna(method ='bfill')
# Out:
# C:\Users\akhta\AppData\Local\Temp\ipykernel_18332\696051116.py:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method ='bfill')
#    First Score  Second Score  Third Score
# 0        100.0          30.0         40.0
# 1         90.0          45.0         40.0
# 2         95.0          56.0         80.0
# 3         95.0           NaN         98.0

# %%
# .Printing the first 10 to 24 rows of the data frame for visualization

data = pd.read_csv("employees.csv")
data[10:25]

data = pd.read_csv("employees.csv")
data["Gender"].fillna("No Gender", inplace = True)
data
# Out:
#     First Name     Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas       Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas       Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria     Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry       Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry       Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...        ...         ...             ...     ...      ...
# 995      Henry  No Gender  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip       Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell       Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry       Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert       Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# ...

# %%
# replace Nan value in dataframe with value -99

import pandas as pd
data = pd.read_csv("employees.csv")
data.replace(to_replace = np.nan, value = -99)
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     -99  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   -99
# ...

# %%
# interpolate the missing values
import pandas as pd
df = pd.DataFrame({"A":[12, 4, 5, None, 1],
 "B":[None, 2, 54, 3, None],
 "C":[20, 16, None, 3, 8],
 "D":[14, 3, None, None, 6]})
df
df.interpolate(method ='linear', limit_direction ='forward')
# Out:
#       A     B     C     D
# 0  12.0   NaN  20.0  14.0
# 1   4.0   2.0  16.0   3.0
# 2   5.0  54.0   9.5   4.0
# 3   3.0   3.0   3.0   5.0
# 4   1.0   3.0   8.0   6.0

# %%
# using dropna() function
import pandas as pd
import numpy as np
dict = {'First Score':[100, 90, np.nan, 95],
 'Second Score': [30, np.nan, 45, 56],
 'Third Score':[52, 40, 80, 98],
 'Fourth Score':[np.nan, np.nan, np.nan, 65]}
df = pd.DataFrame(dict)

# df.dropna()

# df.dropna(how = 'all')

# df.dropna(axis = 1)

# %%
# making new data frame with dropped NA values
import pandas as pd
data = pd.read_csv("employees.csv")
new_data = data.dropna(axis = 0, how ='any')
new_data
print("Old data frame length:", len(data))
print("New data frame length:", len(new_data))
print("Number of rows with at least 1 NA value: ", (len(data)-len(new_data)))
# Out:
# Old data frame length: 1000
# New data frame length: 764
# Number of rows with at least 1 NA value:  236

# %%
# use isna() function to detect the missing values in a dataframe.
import pandas as pd
sr = pd.Series([12, 5, None, 5, None, 11])
sr
sr.isna()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# dtype: bool

# %%
import pandas as pd
import numpy as np
data = pd.read_csv("employees.csv")
print("First 5 values : \n",data.head(),"\n")
print("Mean: \n",data.mean(numeric_only=True),"\n")
print("STD :\n",data.std(numeric_only=True),"\n")
# Out:
# First 5 values :
#    First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services
#
# Mean:
#  Salary     90662.181000
# Bonus %       10.207555
# dtype: float64
#
# STD :
#  Salary     32923.693342
# Bonus %        5.528481
# dtype: float64
